# %%
cd C:\Users\Kevin\PycharmProjects\hubmap\preprocessing
# Out:
# C:\Users\Kevin\PycharmProjects\hubmap\preprocessing

# %%
#random flag makes no difference

# %%
# !python dataset_statistics.py --data-dir "C:\Users\Kevin\Desktop\hubmap\train" --save-dir r"C:\Users\Kevin\PycharmProjects\hubmap\randstain-train" --dataset-name "new-train" --methods "Reinhard" --random
# Out:
# ['0006ff2aa7cd.tif', '000e79e206b7.tif', '00168d1b7522.tif', '00176a88fdb0.tif', '0033bbc76b6b.tif', '003504460b3a.tif', '00359ab8338b.tif', '00488ca285ee.tif', '004daf1cbe75.tif', '004fb033dd09.tif', '0054b93142c4.tif', '005715f0a313.tif', '005a16af0231.tif', '005f05ed625f.tif', '006007019cdb.tif', '00654cc08aac.tif', '00656c6f2690.tif', '0067d5ad2250.tif', '006834048f7b.tif', '006cecb2aaff.tif', '0074999a704e.tif', '0080d3e3b127.tif', '0094b5dc209d.tif', '009eefb152d3.tif', '00a768c3dfa5.tif', '00b30b105c16.tif', '00bc0c5940e1.tif', '00c1aa401009.tif', '00c40c360378.tif', '00c7704a1054.tif', '00c89e5d88dc.tif', '00ca2f4c8918.tif', '00cfa95bc6d4.tif', '00d75ad65de3.tif', '00da70813521.tif', '00da8fdf2391.tif', '00dcb6900b37.tif', '00dec947e4d9.tif', '00e579c5b135.tif', '00eef92a6218.tif', '00f560a6a72b.tif', '00ff2d7b49dc.tif', '0103d61f2a5e.tif', '01043adee542.tif', '011d54084ae1.tif', '0123416f5322.tif', '012b00fda14c.tif', '012ededfa1cf.tif', '012efa4e6d9a.tif', '013862e23aaf.tif
# ...
